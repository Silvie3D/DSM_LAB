# %%
import pandas as pd
dict1={'rollno':[1,2,3,4],'name':["Sam","Sameer","Samuel","Samantha"]}
tableview=pd.DataFrame(dict1)
print(tableview)
# Out:
#    rollno      name
# 0       1       Sam
# 1       2    Sameer
# 2       3    Samuel
# 3       4  Samantha

# %%
import pandas as pd
a=[1,2,3,4]
b=pd.Series(a)
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd
a=[1,2,3,4]
b=pd.Series(a, index=["a","b","c","d"])
print(b)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
import pandas as pd
dict1={'rollno':[1,2,3,4],'name':["Sam","Sameer","Samuel","Samantha"]}
tableview=pd.DataFrame(dict1)
print(tableview.loc[1:])
# Out:
#    rollno      name
# 1       2    Sameer
# 2       3    Samuel
# 3       4  Samantha

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a)
# Out:
#          Fruit  Price
# 0        Apple  180.0
# 1       Banana   60.0
# 2       Orange  120.0
# 3        Mango  150.0
# 4       Grapes  100.0
# 5    Pineapple   80.0
# 6          NaN    NaN
# 7   Watermelon   40.0
# 8       Papaya   70.0
# 9   Strawberry  250.0
# 10       Guava   90.0

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a.head(5))
# Out:
#     Fruit  Price
# 0   Apple    180
# 1  Banana     60
# 2  Orange    120
# 3   Mango    150
# 4  Grapes    100

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a.tail(5))
# Out:
#         Fruit  Price
# 5   Pineapple     80
# 6  Watermelon     40
# 7      Papaya     70
# 8  Strawberry    250
# 9       Guava     90

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a)
b=a.dropna()
print(b)
# Out:
#          Fruit  Price
# 0        Apple  180.0
# 1       Banana   60.0
# 2       Orange  120.0
# 3        Mango  150.0
# 4       Grapes  100.0
# 5    Pineapple   80.0
# 6          NaN    NaN
# 7   Watermelon   40.0
# 8       Papaya   70.0
# 9   Strawberry  250.0
# 10       Guava   90.0
#          Fruit  Price
# 0        Apple  180.0
# 1       Banana   60.0
# 2       Orange  120.0
# 3        Mango  150.0
# 4       Grapes  100.0
# 5    Pineapple   80.0
# 7   Watermelon   40.0
# 8       Papaya   70.0
# 9   Strawberry  250.0
# 10       Guava   90.0

# %%
import pandas as pd
a=pd.read_csv('data.csv')
b = a.fillna({"Fruit": "Null", "Price": 0})
print(b)
# Out:
#          Fruit  Price
# 0        Apple  180.0
# 1       Banana   60.0
# 2       Orange  120.0
# 3        Mango  150.0
# 4       Grapes  100.0
# 5    Pineapple   80.0
# 6         Null    0.0
# 7   Watermelon   40.0
# 8       Papaya   70.0
# 9   Strawberry  250.0
# 10       Guava   90.0
